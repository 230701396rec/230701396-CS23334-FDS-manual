# %%
#Name:Praveenraj
#Regno:230701396
#CS23334-Fundamentals of DataScienceimport numpy as np
import pandas as pd
list=[[1,'Smith',50000],[2,'Jones',60000]]
df=pd.DataFrame(list)
df
# Out:
#    0      1      2
# 0  1  Smith  50000
# 1  2  Jones  60000

# %%
df.columns=['Empd','Name','Salary']
df
# Out:
#    Empd   Name  Salary
# 0     1  Smith   50000
# 1     2  Jones   60000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empd    2 non-null      int64
#  1   Name    2 non-null      object
#  2   Salary  2 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 176.0+ bytes

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Employee_Dataset.csv")

# %%
df.head()
# Out:
#    emp_id         name  salary
# 0       1   John Smith   55000
# 1       2     Jane Doe   62000
# 2       3  Alice Brown   58000
# 3       4  Bob Johnson   49000
# 4       5  Charlie Lee   72000

# %%
df.tail()
# Out:
#    emp_id          name  salary
# 5       6   Diana Evans   67000
# 6       7   Eric Wilson   53000
# 7       8   Fiona Clark   75000
# 8       9   George Hall   46000
# 9      10  Hannah Scott   69000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   emp_id  10 non-null     int64
#  1   name    10 non-null     object
#  2   salary  10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df.salary
# Out:
# 0    55000
# 1    62000
# 2    58000
# 3    49000
# 4    72000
# 5    67000
# 6    53000
# 7    75000
# 8    46000
# 9    69000
# Name: salary, dtype: int64

# %%
type(df.salary)
# Out:
# pandas.core.series.Series

# %%
df.salary.mean()
# Out:
# 60600.0

# %%
df.salary.median()
# Out:
# 60000.0

# %%
df.salary.mode()
# Out:
# 0    46000
# 1    49000
# 2    53000
# 3    55000
# 4    58000
# 5    62000
# 6    67000
# 7    69000
# 8    72000
# 9    75000
# Name: salary, dtype: int64

# %%
df.salary.var()
# Out:
# 99377777.77777778

# %%
df.salary.std()
# Out:
# 9968.840342676664

# %%
df.describe()
# Out:
#          emp_id        salary
# count  10.00000     10.000000
# mean    5.50000  60600.000000
# std     3.02765   9968.840343
# min     1.00000  46000.000000
# 25%     3.25000  53500.000000
# 50%     5.50000  60000.000000
# 75%     7.75000  68500.000000
# max    10.00000  75000.000000

# %%
df.describe(include='all')
# Out:
#           emp_id        name        salary
# count   10.00000          10     10.000000
# unique       NaN          10           NaN
# top          NaN  John Smith           NaN
# freq         NaN           1           NaN
# mean     5.50000         NaN  60600.000000
# std      3.02765         NaN   9968.840343
# min      1.00000         NaN  46000.000000
# 25%      3.25000         NaN  53500.000000
# 50%      5.50000         NaN  60000.000000
# 75%      7.75000         NaN  68500.000000
# max     10.00000         NaN  75000.000000

# %%
empCol=df.columns
empCol
# Out:
# Index(['emp_id', 'name', 'salary'], dtype='object')

# %%
emparray=df.values
emparray
# Out:
# array([[1, 'John Smith', 55000],
#        [2, 'Jane Doe', 62000],
#        [3, 'Alice Brown', 58000],
#        [4, 'Bob Johnson', 49000],
#        [5, 'Charlie Lee', 72000],
#        [6, 'Diana Evans', 67000],
#        [7, 'Eric Wilson', 53000],
#        [8, 'Fiona Clark', 75000],
#        [9, 'George Hall', 46000],
#        [10, 'Hannah Scott', 69000]], dtype=object)

# %%
employee_DF=pd.DataFrame(emparray,columns=empCol)
employee_DF
# Out:
#   emp_id          name salary
# 0      1    John Smith  55000
# 1      2      Jane Doe  62000
# 2      3   Alice Brown  58000
# 3      4   Bob Johnson  49000
# 4      5   Charlie Lee  72000
# 5      6   Diana Evans  67000
# 6      7   Eric Wilson  53000
# 7      8   Fiona Clark  75000
# 8      9   George Hall  46000
# 9     10  Hannah Scott  69000
